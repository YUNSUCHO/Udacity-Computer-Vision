# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import cv2
import numpy as np

# %matplotlib inline



#read the image
image = mpimg.imread('images/curved_lane.jpg')

plt.imshow(image)

# %%
#convert to gry scale

gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

plt.imshow(gray)

# %%
# create a custom filter(kernel)

sobel_y = np.array([[-1,-2,-1],
                   [ 0, 0, 0],
                   [ 1, 2, 1]])

filtered_image_y = cv2.filter2D(gray, -1, sobel_y)

plt.imshow(filtered_image, cmap = 'gray')


sobel_x = np.array([[-1,0,1],
                   [-2,0,2],
                    [-1,0,1]])

filtered_image_x = cv2.filter2D(gray, -1, sobel_x)
                            #(gray sclaed image, bit-depth, kernel)
plt.imshow(filtered_image_x, cmap = 'gray')
