# %%
import cv2
import helpers

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %matplotlib inline

# %%
image_dir_training = "day_night_images/training/"
image_dir_test = "day_night_images/test/"

# %%
#uaing the load_dataset function in helpers.py, load training image
IMAGE_LIST = helpers.load_dataset(image_dir_training)

# %%
#select an image and lits label by list index
image_index = 0
selected_image = IMAGE_LIST[image_index][0]
selected_label = IMAGE_LIST[image_index][1]

print("shape of image: ", selected_image.shape)
print("label of image: ", selected_label)

plt.imshow(selected_image)
# Out:
# shape of image:  (372, 640, 3)
# label of image:  day

# %%
#select an image and lits label by list index
image_index = 200
selected_image = IMAGE_LIST[image_index][0]
selected_label = IMAGE_LIST[image_index][1]

print("shape of image: ", selected_image.shape)
print("label of image: ", selected_label)

plt.imshow(selected_image)
# Out:
# shape of image:  (700, 1280, 3)
# label of image:  night
